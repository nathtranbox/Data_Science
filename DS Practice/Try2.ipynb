# %%
Level 1 - Programming
----------------------
You are a data scientist working in the research labs for a large retail organization.
Currently you task involves mining for insights from Point-of-Sale systems which track item sales.
You have data stored as follows in JSON files (for simplicity think that you have one file 'pos_data.json')

Data Sample:

[{'item': 'Stella Extra Strong', 'price': '$23.45'},
{'item': 'Fosters Mild', 'price': '$12.99'},
{'item': 'Heineken', 'price': '$29.45'},
{'item': 'Stella Extra Strong', 'price': '$23.45'},
{'item': 'Stella Extra Strong', 'price': '$23.45'},
{'item': 'Fosters Mild', 'price': '$12.99'}]


Your tasks are as follows.
1. Write code to read in the JSON file to an appropriate python data structure (to solve Q2)
2. Use base python libraries (not pandas) to get the following insights
 -> Item name with top total sales
 -> Item name with least total sales
 -> Item name with the most units sold

Base Python libraries only (no 3rd party libraries e.g: numpy, pandas)


"""
#import json
#with open('pos_data.json','r') as data_file:
#    data = json.load(data_file)

data = [{'item': 'Stella Extra Strong', 'price': '$23.45'},
{'item': 'Fosters Mild', 'price': '$12.99'},
{'item': 'Heineken', 'price': '$29.45'},
{'item': 'Stella Extra Strong', 'price': '$23.45'},
{'item': 'Stella Extra Strong', 'price': '$23.45'},
{'item': 'Fosters Mild', 'price': '$12.99'}]

item_type = []
for item_record in data:
    if item_record['item'] not in item_type:
        item_type.append(item_record['item'])

print(item_type)

sales_by_type ={}

#remove the '$'
for item_record in data:
    item_record['price'] = float(item_record['price'].replace('$',''))
    
print(data)

for x in item_type:
    sales_by_type[x]=0
    
print(sales_by_type)

for item_record in data:
    if item_record['item'] in item_type:
        sales_by_type[item_record['item']] = sales_by_type[item_record['item']] + item_record[item_record['price']]

# %%
Level 1 - SQL Set 1
--------------------

Let's consider that you now have your data in a structured relational DB.

Table: PosData

|---------------------|---------|
|   item              | price   |
|---------------------|---------|
| Stella Extra Strong |  23.45  |
| Heineken            |  29.45  |
| Fosters Mild        |  12.99  |
| Fosters Mild        |  12.99  |
| ...                 |  ...    |
| ...                 |  ...    |
| ...                 |  ...    |
| Heineken            |  29.45  |
|---------------------|---------|


Write SQL code for the following tasks 

1. Build a item-frequency table showing the number of times each item was sold
2. Build an item-sales table showing each item and its TOTAL sales 
"""

select item, count(item) as frequency from PostData
group by item

select item, sum(price) as TotalSales from PostData
group by item
