# %% [markdown]
# # JSON EXERCISE

# %% [markdown]
# Using data in file 'data/world_bank_projects.json' and the techniques demonstrated above,
#
# Find the 10 countries with most projects
# Find the top 10 major project themes (using column 'mjtheme_namecode')
# In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
# Import pandas and json packages
import pandas as pd
import json

# %%
# Loads the json file as dataframe and looks at the data initially
json_df = pd.read_json('world_bank_projects.json')
json_df.head(3)
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
# 2  [{'Name': 'Rural and Inter-Urban Roads and Hig...                    Y
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 1                OTHER       RE
# 2                  IDA       PE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
# 2  [Trade and integration, Public sector governan...     6060000
#
#                                   impagency  \
# 0                     MINISTRY OF EDUCATION
# 1                       MINISTRY OF FINANCE
# 2  MINISTRY OF TRANSPORT AND COMMUNICATIONS
#
#                                         project_name mjthemecode  \
# ...

# %%
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 50 columns):
# sector                      500 non-null object
# supplementprojectflg        498 non-null object
# projectfinancialtype        500 non-null object
# prodline                    500 non-null object
# mjtheme                     491 non-null object
# idacommamt                  500 non-null int64
# impagency                   472 non-null object
# project_name                500 non-null object
# mjthemecode                 500 non-null object
# closingdate                 370 non-null object
# totalcommamt                500 non-null int64
# id                          500 non-null object
# mjsector_namecode           500 non-null object
# docty                       446 non-null object
# sector1                     500 non-null object
# lendinginstr                495 non-null object
# countrycode                 500 non-null object
# ...

# %% [markdown]
# # 1. Finds 10 countries with the most projects

# %%
json_df['countryname'].value_counts().head(10)
# Out:
# Republic of Indonesia              19
# People's Republic of China         19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# Kingdom of Morocco                 12
# Nepal                              12
# People's Republic of Bangladesh    12
# Africa                             11
# Republic of Mozambique             11
# Name: countryname, dtype: int64

# %% [markdown]
# # 2.Find the top 10 major project themes (using column 'mjtheme_namecode')

# %%
#The column 'mjtheme_namecode' is nested. This will need to be flatterned before we can count major project themes.
#A json string is needed to flattern this
#first is to import json_normalize

# %%
from pandas.io.json import json_normalize

# %%
#load the json file and save as a json string
json_str = json.load((open('world_bank_projects.json')))

# %%
#flatterns the column mjtheme_namecode: json_str
json_str = json_normalize(json_str,'mjtheme_namecode')
json_str.head(10)
# Out:
#   code                                          name
# 0    8                             Human development
# 1   11
# 2    1                           Economic management
# 3    6         Social protection and risk management
# 4    5                         Trade and integration
# 5    2                      Public sector governance
# 6   11  Environment and natural resources management
# 7    6         Social protection and risk management
# 8    7                   Social dev/gender/inclusion
# 9    7                   Social dev/gender/inclusion

# %%
# it appears that some names are missing
# therefore we can count the major themes by utilizing the completely available codes
mjtheme_count = json_str.code.value_counts()

#after counting is done, we call the top 10 major themes and assign to: top10_mjtheme
top10_mjtheme = mjtheme_count.head(10)
top10_mjtheme
# Out:
# 11    250
# 10    216
# 8     210
# 2     199
# 6     168
# 4     146
# 7     130
# 5      77
# 9      50
# 1      38
# Name: code, dtype: int64

# %% [markdown]
# # 3.In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
#handling missing data in this case can be done by filling backward functionality. This will include three steps
# (1) sorting 
# (2) replacing missing data ('') with NaN (will need numpy)
# (3) fill backward

#import numpy as np
import numpy as np

# %%
# sort by 'code' and 'name'
json_str = json_str.sort_values(['code','name'])
json_str.head(10)
# Out:
#      code                 name
# 212     1
# 363     1
# 1024    1
# 1114    1
# 1437    1
# 2       1  Economic management
# 88      1  Economic management
# 175     1  Economic management
# 204     1  Economic management
# 205     1  Economic management

# %%
#the space in the empty cells can be replaced with NaN
json_str.name[json_str['name']==''] = np.nan
json_str.head(10)
# Out:
#      code                 name
# 212     1                  NaN
# 363     1                  NaN
# 1024    1                  NaN
# 1114    1                  NaN
# 1437    1                  NaN
# 2       1  Economic management
# 88      1  Economic management
# 175     1  Economic management
# 204     1  Economic management
# 205     1  Economic management

# %%
#fills the missing values in an backward manner
json_str = json_str.fillna(method ='bfill')
json_str.head(10)
# Out:
#      code                 name
# 212     1  Economic management
# 363     1  Economic management
# 1024    1  Economic management
# 1114    1  Economic management
# 1437    1  Economic management
# 2       1  Economic management
# 88      1  Economic management
# 175     1  Economic management
# 204     1  Economic management
# 205     1  Economic management

# %%
#now we can count the top 10 major themes by name

top10_mjtheme = json_str.name.value_counts().head(10)
top10_mjtheme
# Out:
# Environment and natural resources management    250
# Rural development                               216
# Human development                               210
# Public sector governance                        199
# Social protection and risk management           168
# Financial and private sector development        146
# Social dev/gender/inclusion                     130
# Trade and integration                            77
# Urban development                                50
# Economic management                              38
# Name: name, dtype: int64
